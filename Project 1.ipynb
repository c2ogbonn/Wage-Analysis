# %%
print('Hello!')
# Out:
# Hello!

# %%
for i in range(1):
    print (i)
# Out:
# 0

# %%
import pandas as pd

# %%
path = '~/Downloads/COURSERA/_1302613530cb30ef46530687365e64d9_salary_data_states_corrected.xlsx'
df = pd.read_excel(path)

# %%
df.head(5)
# Out:
#           CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  I-200-14073-248840      denied          3/14/2014     3/21/2014
# 1       A-15061-55212      denied          3/19/2015     3/19/2015
# 2  I-200-13256-001092      denied          9/13/2013     9/23/2013
# 3  I-200-14087-353657      denied          3/28/2014      4/7/2014
# 4  I-203-14259-128844      denied          9/16/2014     9/23/2014
#
#                                        EMPLOYER_NAME  \
# 0                ADVANCED TECHNOLOGY GROUP USA, INC.
# 1                     SAN FRANCISCO STATE UNIVERSITY
# 2                                    CAROUSEL SCHOOL
# 3  HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DIST...
# 4                        SIGNAL SCIENCES CORPORATION
#
#    PREVAILING_WAGE_SUBMITTED PREVAILING_WAGE_SUBMITTED_UNIT  \
# 0                  6217100.0                           year
# 1                  5067600.0                           year
# ...

# %%
print(df.dtypes)
# Out:
# CASE_NUMBER                        object
# CASE_STATUS                        object
# CASE_RECEIVED_DATE                 object
# DECISION_DATE                      object
# EMPLOYER_NAME                      object
# PREVAILING_WAGE_SUBMITTED         float64
# PREVAILING_WAGE_SUBMITTED_UNIT     object
# PAID_WAGE_SUBMITTED               float64
# PAID_WAGE_SUBMITTED_UNIT           object
# JOB_TITLE                          object
# WORK_CITY                          object
# EDUCATION_LEVEL_REQUIRED           object
# COLLEGE_MAJOR_REQUIRED             object
# EXPERIENCE_REQUIRED_Y_N            object
# EXPERIENCE_REQUIRED_NUM_MONTHS    float64
# COUNTRY_OF_CITIZENSHIP             object
# PREVAILING_WAGE_SOC_CODE           object
# PREVAILING_WAGE_SOC_TITLE          object
# WORK_STATE                         object
# WORK_STATE_ABBREVIATION            object
# WORK_POSTAL_CODE                   object
# FULL_TIME_POSITION_Y_N             object
# ...

# %%
df.describe()
# Out:
#        PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED  \
# count               1.672780e+05         1.672780e+05
# mean                7.115752e+04         8.164186e+04
# std                 3.874624e+04         4.147703e+04
# min                 5.050000e+00         5.050000e+00
# 25%                 5.447500e+04         6.100000e+04
# 50%                 6.970100e+04         7.700000e+04
# 75%                 8.993700e+04         1.000000e+05
# max                 6.217100e+06         2.500000e+06
#
#        EXPERIENCE_REQUIRED_NUM_MONTHS  PREVAILING_WAGE_PER_YEAR  \
# count                     4965.000000             167210.000000
# mean                        34.692044              74274.868236
# std                         22.317783              25356.245893
# min                          0.000000              10504.000000
# 25%                         12.000000              56880.000000
# 50%                         24.000000              70928.000000
# ...

# %%
df[['PREVAILING_WAGE_SUBMITTED']].describe()
# Out:
#        PREVAILING_WAGE_SUBMITTED
# count               1.672780e+05
# mean                7.115752e+04
# std                 3.874624e+04
# min                 5.050000e+00
# 25%                 5.447500e+04
# 50%                 6.970100e+04
# 75%                 8.993700e+04
# max                 6.217100e+06

# %%
df.head(1)
# Out:
#           CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  I-200-14073-248840      denied          3/14/2014     3/21/2014
#
#                          EMPLOYER_NAME  PREVAILING_WAGE_SUBMITTED  \
# 0  ADVANCED TECHNOLOGY GROUP USA, INC.                  6217100.0
#
#   PREVAILING_WAGE_SUBMITTED_UNIT  PAID_WAGE_SUBMITTED  \
# 0                           year              62171.0
#
#   PAID_WAGE_SUBMITTED_UNIT          JOB_TITLE  ...   \
# 0                     year  SOFTWARE ENGINEER  ...
#
#            PREVAILING_WAGE_SOC_TITLE WORK_STATE WORK_STATE_ABBREVIATION  \
# 0  Software Developers, Applications   Illinois                      IL
#
#   WORK_POSTAL_CODE  FULL_TIME_POSITION_Y_N VISA_CLASS  \
# 0              NaN                       y       H-1B
#
#   PREVAILING_WAGE_PER_YEAR PAID_WAGE_PER_YEAR JOB_TITLE_SUBGROUP order
# 0                      NaN            62171.0  software engineer     1
#
# [1 rows x 27 columns]

# %%
df.corr()
# Out:
#                                 PREVAILING_WAGE_SUBMITTED  \
# PREVAILING_WAGE_SUBMITTED                        1.000000
# PAID_WAGE_SUBMITTED                              0.579431
# EXPERIENCE_REQUIRED_NUM_MONTHS                   0.538603
# PREVAILING_WAGE_PER_YEAR                         0.859242
# PAID_WAGE_PER_YEAR                               0.441753
# order                                           -0.649335
#
#                                 PAID_WAGE_SUBMITTED  \
# PREVAILING_WAGE_SUBMITTED                  0.579431
# PAID_WAGE_SUBMITTED                        1.000000
# EXPERIENCE_REQUIRED_NUM_MONTHS             0.384335
# PREVAILING_WAGE_PER_YEAR                   0.629122
# PAID_WAGE_PER_YEAR                         0.877163
# order                                     -0.589391
#
#                                 EXPERIENCE_REQUIRED_NUM_MONTHS  \
# PREVAILING_WAGE_SUBMITTED                             0.538603
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.regplot(x="PAID_WAGE_SUBMITTED", y="PAID_WAGE_PER_YEAR", data=df)
#plt.ylim(0,)
plt.ylim(0,)
plt.xlim(0,)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df[['PAID_WAGE_SUBMITTED','PAID_WAGE_PER_YEAR']].corr()
# Out:
#                      PAID_WAGE_SUBMITTED  PAID_WAGE_PER_YEAR
# PAID_WAGE_SUBMITTED             1.000000            0.877163
# PAID_WAGE_PER_YEAR              0.877163            1.000000

# %%
df[['PAID_WAGE_SUBMITTED']].describe()
# Out:
#        PAID_WAGE_SUBMITTED
# count         1.672780e+05
# mean          8.164186e+04
# std           4.147703e+04
# min           5.050000e+00
# 25%           6.100000e+04
# 50%           7.700000e+04
# 75%           1.000000e+05
# max           2.500000e+06

# %%
df[['PAID_WAGE_PER_YEAR']].describe()
# Out:
#        PAID_WAGE_PER_YEAR
# count        1.672780e+05
# mean         8.553277e+04
# std          3.873847e+04
# min          1.050000e+04
# 25%          6.300000e+04
# 50%          7.860000e+04
# 75%          1.000060e+05
# max          2.500000e+06
